# %%
# 1 -  importation des librairies

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from time import time
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Dropout
from keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
# 2 - importation des données 

dataset_full=pd.read_csv("https://raw.githubusercontent.com/oreilly-mlsec/book-resources/599669c7124dffb65ea7f6e0b7626df32496b1d6/chapter3/datasets/cpu-utilization/cpu-full-a.csv",sep=',')
dataset_training=pd.read_csv("https://raw.githubusercontent.com/oreilly-mlsec/book-resources/599669c7124dffb65ea7f6e0b7626df32496b1d6/chapter3/datasets/cpu-utilization/cpu-train-a.csv", sep=",")
dataset_test=pd.read_csv("https://raw.githubusercontent.com/oreilly-mlsec/book-resources/599669c7124dffb65ea7f6e0b7626df32496b1d6/chapter3/datasets/cpu-utilization/cpu-test-a.csv", sep=",")

dataset_full['date']=pd.to_datetime(dataset_full.datetime)
dataset_training['date']=pd.to_datetime(dataset_training.datetime)
dataset_test['date']=pd.to_datetime(dataset_test.datetime)
dataset_full=dataset_full[['date','cpu']]

# %%
# 3 - Séparation des données d'apprentissage et de test

# 3.1 - : Processing des données

scaler = MinMaxScaler(feature_range = (0, 1))

train=scaler.fit_transform(dataset_training[['cpu']])

test=scaler.fit_transform(dataset_test[['cpu']])

dataset=scaler.fit_transform(dataset_full[['cpu']])

# %%
#3.2 - Verification
# print(train.head(),test.head())
timesteps = 5
n_features=1

# 3.3 : fonction de préparation des données
def preparation_data(data,lags):
	x_train = []
	y_train = []
	for i in range(lags,len(data)):
		x_train.append(data[i-lags:i, 0])
		y_train.append(data[i, 0])
	return np.array(x_train), np.array(y_train)
# 3.4 : reshaping des données pour etre mis en RNN-LSTM For [sample,timesteps,n_features]
x_train, y_train=preparation_data(train,timesteps)
x_test, y_test=preparation_data(test,timesteps)
x_dataset_full, y_dataset_full=preparation_data(dataset,timesteps)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
x_dataset_full = np.reshape(x_dataset_full, (x_dataset_full.shape[0], x_dataset_full.shape[1], 1))
# print(x_train.shape,x_test.shape,x_dataset_full.shape)
# (415, 5, 1) (55, 5, 1) (475, 5, 1)

# %%
# 4 : création et mis en place du RNN-LSTM auto-Encoder
start=time()
# define model
model = Sequential()
model.add(LSTM(100, input_shape=(timesteps,n_features), return_sequences=True))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32,return_sequences=False))
model.add(RepeatVector(timesteps))
model.add(LSTM(32, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100,return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.compile(optimizer='rmsprop', loss='mean_squared_error')
model.summary()
# fit model
history=model.fit(x_dataset_full, x_dataset_full, epochs=500,batch_size=5,verbose=1,
                  validation_split=0.10)
# 4.1.4: Architecture

plot_model(model, show_shapes=True, to_file='Architecture hybride Auto-Encoder-Prédicteur.png')
elapsed=time()-start
print('duree totale est de :',elapsed/60)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 5, 100)            40800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 5, 128)            117248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 5, 64)             49408
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 5, 32)             0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 5, 32)             8320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 32)             0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 5, 64)             24832
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 64)             0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 5, 128)            98816
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 5, 100)            91600
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 5, 1)              101
# =================================================================
# Total params: 443,541
# Trainable params: 443,541
# Non-trainable params: 0
# _________________________________________________________________
# Train on 427 samples, validate on 48 samples
# Epoch 1/500
# 427/427 [==============================] - 7s 16ms/step - loss: 0.0582 - val_loss: 0.0114
# Epoch 2/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0170 - val_loss: 0.0170
# Epoch 3/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0097 - val_loss: 0.0025
# Epoch 4/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0081 - val_loss: 0.0165
# Epoch 5/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0020
# Epoch 6/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 7/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 8/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0063 - val_loss: 0.0033
# Epoch 9/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0057 - val_loss: 0.0033
# Epoch 10/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0058 - val_loss: 0.0013
# Epoch 11/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 12/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 13/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0051 - val_loss: 0.0014
# Epoch 14/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0052 - val_loss: 0.0071
# Epoch 15/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0051 - val_loss: 0.0104
# Epoch 16/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 17/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0048 - val_loss: 0.0017
# Epoch 18/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0045 - val_loss: 9.0706e-04
# Epoch 19/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0049 - val_loss: 8.5465e-04
# Epoch 20/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0045 - val_loss: 0.0019
# Epoch 21/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 22/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 23/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 24/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0039 - val_loss: 8.9879e-04
# Epoch 25/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 26/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 27/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 28/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0033 - val_loss: 9.8293e-04
# Epoch 29/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 30/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 31/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 32/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 33/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0033 - val_loss: 8.9702e-04
# Epoch 34/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 35/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0032 - val_loss: 7.7793e-04
# Epoch 36/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0030 - val_loss: 9.9820e-04
# Epoch 37/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 38/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 39/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 40/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 41/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 9.7162e-04
# Epoch 42/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 43/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0028 - val_loss: 7.5157e-04
# Epoch 44/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 7.8234e-04
# Epoch 45/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 9.2938e-04
# Epoch 46/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 47/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 48/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 6.4003e-04
# Epoch 49/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 50/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0026 - val_loss: 5.8944e-04
# Epoch 51/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 0.0011
# Epoch 52/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 0.0011
# Epoch 53/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0024 - val_loss: 0.0015
# Epoch 54/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 8.8125e-04
# Epoch 55/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0027 - val_loss: 6.1184e-04
# Epoch 56/500
# 427/427 [==============================] - 3s 8ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 57/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0024 - val_loss: 3.8614e-04
# Epoch 58/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0026 - val_loss: 5.1267e-04
# Epoch 59/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 60/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0024 - val_loss: 0.0052
# Epoch 61/500
# 427/427 [==============================] - 3s 8ms/step - loss: 0.0024 - val_loss: 9.1230e-04
# Epoch 62/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 63/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0023 - val_loss: 6.0332e-04
# Epoch 64/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0024 - val_loss: 6.4067e-04
# Epoch 65/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0023 - val_loss: 7.2099e-04
# Epoch 66/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0023 - val_loss: 4.7864e-04
# Epoch 67/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0022 - val_loss: 6.1938e-04
# Epoch 68/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 69/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0021 - val_loss: 0.0017s -
# Epoch 70/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0023 - val_loss: 4.5637e-04
# Epoch 71/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 72/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 3.8508e-04
# Epoch 73/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 4.9622e-04
# Epoch 74/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 4.6963e-04
# Epoch 75/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 76/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 77/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 78/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0021 - val_loss: 9.7486e-04
# Epoch 79/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0019 - val_loss: 6.5637e-04
# Epoch 80/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 4.8489e-04
# Epoch 81/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 82/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 83/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 5.8429e-04
# Epoch 84/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0019 - val_loss: 6.9318e-04
# Epoch 85/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 7.3230e-04
# Epoch 86/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 87/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 88/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 7.8680e-04
# Epoch 89/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 5.2661e-04
# Epoch 90/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 91/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 92/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 93/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 4.0795e-04
# Epoch 94/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0017 - val_loss: 3.1845e-04
# Epoch 95/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 96/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0017 - val_loss: 4.9402e-04
# Epoch 97/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0016 - val_loss: 4.6154e-04
# Epoch 98/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0016 - val_loss: 6.6913e-04
# Epoch 99/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0018 - val_loss: 3.3852e-04
# Epoch 100/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 9.9906e-04
# Epoch 101/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - val_loss: 6.8413e-04
# Epoch 102/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - val_loss: 2.6743e-04
# Epoch 103/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 5.9888e-04
# Epoch 104/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 3.5216e-04
# Epoch 105/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 6.6011e-04
# Epoch 106/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 7.8890e-04
# Epoch 107/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 9.2951e-04
# Epoch 108/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - val_loss: 2.4399e-04
# Epoch 109/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 110/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 111/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 7.3266e-04
# Epoch 112/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 4.2324e-04
# Epoch 113/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 8.8925e-04
# Epoch 114/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 3.4672e-04
# Epoch 115/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 4.2029e-04
# Epoch 116/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0015 - val_loss: 2.8423e-04
# Epoch 117/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 2.1705e-04
# Epoch 118/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 9.6321e-04
# Epoch 119/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 7.8696e-04
# Epoch 120/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 121/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 4.0025e-04
# Epoch 122/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 123/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 3.4241e-04
# Epoch 124/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 5.7230e-04
# Epoch 125/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 9.5662e-04
# Epoch 126/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 3.2398e-04
# Epoch 127/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 2.9892e-04
# Epoch 128/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 129/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 8.9347e-04
# Epoch 130/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 4.6063e-04
# Epoch 131/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 132/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 5.8482e-04
# Epoch 133/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 6.1031e-04
# Epoch 134/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 135/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 7.7935e-04
# Epoch 136/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 137/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 6.7985e-04
# Epoch 138/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 2.2043e-04
# Epoch 139/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 3.2146e-04
# Epoch 140/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 7.1705e-04
# Epoch 141/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 3.1912e-04
# Epoch 142/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 4.3415e-04
# Epoch 143/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 4.5529e-04
# Epoch 144/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 145/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 8.9836e-04
# Epoch 146/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 1.9767e-04
# Epoch 147/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 6.2279e-04
# Epoch 148/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 149/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 2.2864e-04
# Epoch 150/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 5.9455e-04
# Epoch 151/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 8.8349e-04
# Epoch 152/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 6.2955e-04
# Epoch 153/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 154/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 9.8986e-04
# Epoch 155/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 5.1841e-04
# Epoch 156/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 4.4149e-04
# Epoch 157/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 6.1813e-04
# Epoch 158/500
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 2.4761e-04
# Epoch 159/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 4.7057e-04
# Epoch 160/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 9.0966e-04
# Epoch 161/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 162/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 6.0794e-04
# Epoch 163/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 6.6159e-04
# Epoch 164/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 8.3413e-04
# Epoch 165/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 4.6926e-04
# Epoch 166/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 1.9980e-044e - ETA: 1
# Epoch 167/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 2.4541e-04
# Epoch 168/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 2.0986e-04
# Epoch 169/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 7.0440e-04
# Epoch 170/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 6.6760e-04
# Epoch 171/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 3.2758e-04
# Epoch 172/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 2.8057e-04
# Epoch 173/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 174/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.8059e-04 - val_loss: 7.6801e-04
# Epoch 175/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 5.3369e-04
# Epoch 176/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 9.3650e-04
# Epoch 177/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 3.1377e-04
# Epoch 178/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 8.0289e-04
# Epoch 179/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.7115e-04 - val_loss: 6.5019e-04
# Epoch 180/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 3.1644e-04
# Epoch 181/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.8641e-04 - val_loss: 6.5089e-04
# Epoch 182/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.8382e-04 - val_loss: 2.6557e-04
# Epoch 183/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.8924e-04 - val_loss: 6.0670e-040
# Epoch 184/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 6.8936e-04
# Epoch 185/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.5598e-04 - val_loss: 8.8991e-04
# Epoch 186/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.2299e-04 - val_loss: 9.7989e-04
# Epoch 187/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.5258e-04 - val_loss: 8.8773e-04
# Epoch 188/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.7790e-04 - val_loss: 5.8532e-04
# Epoch 189/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.6460e-04 - val_loss: 3.7350e-04
# Epoch 190/500
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 7.0101e-04
# Epoch 191/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.7268e-04 - val_loss: 6.1553e-04
# Epoch 192/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.8340e-04 - val_loss: 2.9631e-04
# Epoch 193/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.3172e-04 - val_loss: 9.1830e-04
# Epoch 194/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.1736e-04 - val_loss: 3.1268e-04
# Epoch 195/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.5836e-04 - val_loss: 3.7364e-04
# Epoch 196/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.9865e-04 - val_loss: 0.0010
# Epoch 197/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.9031e-04 - val_loss: 0.0012
# Epoch 198/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.9552e-04 - val_loss: 9.5408e-04
# Epoch 199/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.7303e-04 - val_loss: 5.4775e-04
# Epoch 200/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.5804e-04 - val_loss: 2.1098e-04
# Epoch 201/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.3466e-04 - val_loss: 4.2620e-04
# Epoch 202/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.9151e-04 - val_loss: 4.6938e-04
# Epoch 203/500
# 427/427 [==============================] - 3s 8ms/step - loss: 8.9084e-04 - val_loss: 5.7581e-04
# Epoch 204/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8156e-04 - val_loss: 3.2663e-04
# Epoch 205/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8356e-04 - val_loss: 3.4490e-04
# Epoch 206/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.4075e-04 - val_loss: 3.5548e-04
# Epoch 207/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8860e-04 - val_loss: 0.0010
# Epoch 208/500
# 427/427 [==============================] - 3s 7ms/step - loss: 9.3734e-04 - val_loss: 2.4962e-04
# Epoch 209/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.6226e-04 - val_loss: 2.4664e-04
# Epoch 210/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.4718e-04 - val_loss: 1.7443e-04
# Epoch 211/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.0647e-04 - val_loss: 4.4510e-04
# Epoch 212/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.4595e-04 - val_loss: 2.3095e-04
# Epoch 213/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.2402e-04 - val_loss: 3.7001e-04
# Epoch 214/500
# 427/427 [==============================] - 3s 6ms/step - loss: 9.4154e-04 - val_loss: 2.9093e-04
# Epoch 215/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.5554e-04 - val_loss: 3.8121e-04s: 8.7 - ETA: 0s - loss: 8.6135e
# Epoch 216/500
# 427/427 [==============================] - 3s 7ms/step - loss: 8.3475e-04 - val_loss: 3.6118e-04
# Epoch 217/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.1688e-04 - val_loss: 3.0242e-04
# Epoch 218/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.8783e-04 - val_loss: 0.0012
# Epoch 219/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.3690e-04 - val_loss: 1.6936e-04
# Epoch 220/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.2438e-04 - val_loss: 3.6985e-04
# Epoch 221/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.4182e-04 - val_loss: 2.5839e-04
# Epoch 222/500
# 427/427 [==============================] - 3s 7ms/step - loss: 7.4032e-04 - val_loss: 6.9537e-04
# Epoch 223/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.7781e-04 - val_loss: 3.1555e-04
# Epoch 224/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.6178e-04 - val_loss: 2.9981e-04
# Epoch 225/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.4739e-04 - val_loss: 4.8959e-04
# Epoch 226/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.8964e-04 - val_loss: 1.8128e-04
# Epoch 227/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.8046e-04 - val_loss: 2.0303e-04
# Epoch 228/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.4762e-04 - val_loss: 0.0011
# Epoch 229/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.3085e-04 - val_loss: 5.8318e-04
# Epoch 230/500
# 427/427 [==============================] - 3s 6ms/step - loss: 8.1089e-04 - val_loss: 7.8394e-04
# Epoch 231/500
# 427/427 [==============================] - 3s 7ms/step - loss: 7.7669e-04 - val_loss: 3.8186e-04
# Epoch 232/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.1479e-04 - val_loss: 3.8877e-04
# Epoch 233/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.7201e-04 - val_loss: 4.5138e-04
# Epoch 234/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.7682e-04 - val_loss: 6.0987e-04
# Epoch 235/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.3639e-04 - val_loss: 0.0013ss: 7.
# Epoch 236/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.9290e-04 - val_loss: 0.0011
# Epoch 237/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.4293e-04 - val_loss: 2.5641e-04
# Epoch 238/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.2576e-04 - val_loss: 1.7834e-04
# Epoch 239/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.2583e-04 - val_loss: 2.8954e-04
# Epoch 240/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.7941e-04 - val_loss: 0.0012: 0s -
# Epoch 241/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.7417e-04 - val_loss: 6.5946e-04
# Epoch 242/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.4405e-04 - val_loss: 5.0827e-04
# Epoch 243/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.5458e-04 - val_loss: 2.2708e-04
# Epoch 244/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.0133e-04 - val_loss: 6.3065e-04
# Epoch 245/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.0186e-04 - val_loss: 0.0016
# Epoch 246/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.5581e-04 - val_loss: 2.6182e-04
# Epoch 247/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.4254e-04 - val_loss: 3.4124e-04
# Epoch 248/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.0184e-04 - val_loss: 9.7526e-04
# Epoch 249/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.4605e-04 - val_loss: 8.0968e-04
# Epoch 250/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.5693e-04 - val_loss: 5.6817e-04
# Epoch 251/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.6443e-04 - val_loss: 4.7042e-04
# Epoch 252/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.7774e-04 - val_loss: 4.1697e-04
# Epoch 253/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.2374e-04 - val_loss: 3.2871e-04
# Epoch 254/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.7905e-04 - val_loss: 1.5522e-04
# Epoch 255/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.7601e-04 - val_loss: 3.6588e-04
# Epoch 256/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.2099e-04 - val_loss: 1.4290e-04
# Epoch 257/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.6716e-04 - val_loss: 5.0437e-04
# Epoch 258/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.1826e-04 - val_loss: 2.8027e-04
# Epoch 259/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.8899e-04 - val_loss: 5.6559e-04
# Epoch 260/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.8777e-04 - val_loss: 4.1978e-04
# Epoch 261/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.0193e-04 - val_loss: 0.0015
# Epoch 262/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.5000e-04 - val_loss: 2.8739e-04
# Epoch 263/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.8834e-04 - val_loss: 3.9428e-04
# Epoch 264/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.6726e-04 - val_loss: 1.7564e-04
# Epoch 265/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.5752e-04 - val_loss: 3.3439e-04
# Epoch 266/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.7320e-04 - val_loss: 1.4785e-04
# Epoch 267/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.2571e-04 - val_loss: 3.8282e-04
# Epoch 268/500
# 427/427 [==============================] - 3s 6ms/step - loss: 7.0943e-04 - val_loss: 3.4670e-04
# Epoch 269/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.6247e-04 - val_loss: 4.1664e-04
# Epoch 270/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.5420e-04 - val_loss: 4.1270e-04
# Epoch 271/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.4905e-04 - val_loss: 2.7685e-04
# Epoch 272/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.8779e-04 - val_loss: 1.5860e-04: 0s - loss: 6.9363e
# Epoch 273/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.5291e-04 - val_loss: 2.4675e-04
# Epoch 274/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.5685e-04 - val_loss: 2.7080e-04
# Epoch 275/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.2160e-04 - val_loss: 4.0791e-04
# Epoch 276/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.7850e-04 - val_loss: 2.1507e-04
# Epoch 277/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.6824e-04 - val_loss: 1.4464e-04
# Epoch 278/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.0087e-04 - val_loss: 5.2723e-04o
# Epoch 279/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.7986e-04 - val_loss: 3.0135e-04
# Epoch 280/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.4715e-04 - val_loss: 3.3926e-04
# Epoch 281/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.8939e-04 - val_loss: 2.7040e-04
# Epoch 282/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.0712e-04 - val_loss: 7.7905e-04
# Epoch 283/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.4953e-04 - val_loss: 2.0579e-04
# Epoch 284/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.3641e-04 - val_loss: 5.1379e-04
# Epoch 285/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.1682e-04 - val_loss: 3.3634e-04
# Epoch 286/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.3551e-04 - val_loss: 1.6882e-04
# Epoch 287/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.1085e-04 - val_loss: 1.7075e-04
# Epoch 288/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.0140e-04 - val_loss: 2.1621e-04
# Epoch 289/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.7188e-04 - val_loss: 0.0017 - ETA:
# Epoch 290/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.4071e-04 - val_loss: 1.8916e-04
# Epoch 291/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.3298e-04 - val_loss: 3.5590e-04
# Epoch 292/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.2663e-04 - val_loss: 1.4261e-04
# Epoch 293/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.8222e-04 - val_loss: 1.7108e-04
# Epoch 294/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.9146e-04 - val_loss: 2.0166e-04
# Epoch 295/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.1292e-04 - val_loss: 3.4667e-04
# Epoch 296/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.8851e-04 - val_loss: 1.5075e-04
# Epoch 297/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.2214e-04 - val_loss: 2.3791e-04
# Epoch 298/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.5959e-04 - val_loss: 4.4657e-04
# Epoch 299/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.5188e-04 - val_loss: 5.0598e-04
# Epoch 300/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.7605e-04 - val_loss: 3.3778e-04
# Epoch 301/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.5832e-04 - val_loss: 1.5813e-04
# Epoch 302/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.2836e-04 - val_loss: 7.0586e-04
# Epoch 303/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.8377e-04 - val_loss: 1.4119e-04
# Epoch 304/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.5541e-04 - val_loss: 2.5301e-04
# Epoch 305/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.3847e-04 - val_loss: 1.7750e-04
# Epoch 306/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.0210e-04 - val_loss: 7.6030e-04
# Epoch 307/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.3617e-04 - val_loss: 4.3990e-04
# Epoch 308/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.9340e-04 - val_loss: 1.5275e-04
# Epoch 309/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.5997e-04 - val_loss: 1.8554e-04
# Epoch 310/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.6835e-04 - val_loss: 2.0324e-04
# Epoch 311/500
# 427/427 [==============================] - 3s 6ms/step - loss: 6.0412e-04 - val_loss: 4.8314e-04
# Epoch 312/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.4534e-04 - val_loss: 4.3681e-04
# Epoch 313/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.8276e-04 - val_loss: 6.5614e-04
# Epoch 314/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.5653e-04 - val_loss: 7.9428e-04
# Epoch 315/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.3839e-04 - val_loss: 7.4404e-04
# Epoch 316/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.6403e-04 - val_loss: 5.7947e-04
# Epoch 317/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.9573e-04 - val_loss: 2.5671e-04
# Epoch 318/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.7602e-04 - val_loss: 1.8919e-04
# Epoch 319/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.2330e-04 - val_loss: 1.5818e-04
# Epoch 320/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.4268e-04 - val_loss: 2.5318e-04
# Epoch 321/500
# 427/427 [==============================] - 3s 7ms/step - loss: 6.0117e-04 - val_loss: 6.8213e-04
# Epoch 322/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.5935e-04 - val_loss: 3.2834e-04
# Epoch 323/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.7427e-04 - val_loss: 2.0380e-04
# Epoch 324/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.5874e-04 - val_loss: 2.8937e-04
# Epoch 325/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.1387e-04 - val_loss: 3.2866e-04
# Epoch 326/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.4560e-04 - val_loss: 0.0011
# Epoch 327/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.3047e-04 - val_loss: 1.5003e-04
# Epoch 328/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.2572e-04 - val_loss: 3.2870e-04
# Epoch 329/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.3078e-04 - val_loss: 1.4614e-04
# Epoch 330/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.8478e-04 - val_loss: 2.5502e-04
# Epoch 331/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.8507e-04 - val_loss: 5.5225e-04A: 0s - loss: 4.7757e-0
# Epoch 332/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.9741e-04 - val_loss: 1.7447e-04
# Epoch 333/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.3090e-04 - val_loss: 7.6942e-04 -
# Epoch 334/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.3725e-04 - val_loss: 3.1701e-04
# Epoch 335/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.2990e-04 - val_loss: 3.8992e-04
# Epoch 336/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.4430e-04 - val_loss: 7.1186e-04
# Epoch 337/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.3422e-04 - val_loss: 1.8243e-04
# Epoch 338/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.0501e-04 - val_loss: 4.6011e-04
# Epoch 339/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.3384e-04 - val_loss: 6.8968e-04
# Epoch 340/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.8638e-04 - val_loss: 3.4299e-04
# Epoch 341/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.8066e-04 - val_loss: 4.9434e-04
# Epoch 342/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.0342e-04 - val_loss: 1.9071e-04
# Epoch 343/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.0951e-04 - val_loss: 2.0723e-04
# Epoch 344/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.0048e-04 - val_loss: 1.9510e-04
# Epoch 345/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.9201e-04 - val_loss: 5.8306e-04
# Epoch 346/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.9419e-04 - val_loss: 4.6381e-04
# Epoch 347/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.9216e-04 - val_loss: 1.4402e-04
# Epoch 348/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.2643e-04 - val_loss: 1.5145e-04
# Epoch 349/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.4998e-04 - val_loss: 2.1892e-04
# Epoch 350/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.1274e-04 - val_loss: 2.7339e-04
# Epoch 351/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.7035e-04 - val_loss: 9.1581e-04
# Epoch 352/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.0680e-04 - val_loss: 3.6737e-04
# Epoch 353/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.7652e-04 - val_loss: 3.3736e-04
# Epoch 354/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.2474e-04 - val_loss: 1.7070e-04
# Epoch 355/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.5269e-04 - val_loss: 4.2470e-04
# Epoch 356/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.6593e-04 - val_loss: 6.6861e-04
# Epoch 357/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.7392e-04 - val_loss: 7.8072e-04
# Epoch 358/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.0716e-04 - val_loss: 8.8361e-04
# Epoch 359/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.5537e-04 - val_loss: 4.0483e-04
# Epoch 360/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.5400e-04 - val_loss: 3.1898e-04
# Epoch 361/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.1864e-04 - val_loss: 7.8983e-04
# Epoch 362/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.5744e-04 - val_loss: 1.7234e-04 - ET
# Epoch 363/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.6972e-04 - val_loss: 2.1981e-04
# Epoch 364/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.8586e-04 - val_loss: 3.6635e-04
# Epoch 365/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4347e-04 - val_loss: 1.6365e-04
# Epoch 366/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.7747e-04 - val_loss: 2.4566e-04
# Epoch 367/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.5823e-04 - val_loss: 4.1441e-04
# Epoch 368/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.1906e-04 - val_loss: 1.6347e-04
# Epoch 369/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.7498e-04 - val_loss: 2.6352e-04
# Epoch 370/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.5263e-04 - val_loss: 1.8383e-04
# Epoch 371/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4226e-04 - val_loss: 2.3577e-04
# Epoch 372/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.9250e-04 - val_loss: 1.8254e-04
# Epoch 373/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4989e-04 - val_loss: 5.0595e-04
# Epoch 374/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.6007e-04 - val_loss: 1.6326e-04
# Epoch 375/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.8933e-04 - val_loss: 3.6959e-04
# Epoch 376/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.8591e-04 - val_loss: 6.3700e-04 0s - loss: 4.9006e
# Epoch 377/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.5973e-04 - val_loss: 8.9804e-04
# Epoch 378/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3881e-04 - val_loss: 3.7187e-04
# Epoch 379/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3050e-04 - val_loss: 3.0675e-04s: 4.315
# Epoch 380/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3993e-04 - val_loss: 3.6082e-04
# Epoch 381/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4895e-04 - val_loss: 7.5776e-04
# Epoch 382/500
# 427/427 [==============================] - 3s 6ms/step - loss: 5.1393e-04 - val_loss: 1.6970e-04
# Epoch 383/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2640e-04 - val_loss: 2.3904e-04
# Epoch 384/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2312e-04 - val_loss: 2.3169e-04
# Epoch 385/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.5362e-04 - val_loss: 5.3870e-04
# Epoch 386/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.7823e-04 - val_loss: 4.3260e-04
# Epoch 387/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.8046e-04 - val_loss: 5.1099e-04
# Epoch 388/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.3886e-04 - val_loss: 1.8749e-04
# Epoch 389/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.3686e-04 - val_loss: 2.5583e-04
# Epoch 390/500
# 427/427 [==============================] - 3s 7ms/step - loss: 5.0559e-04 - val_loss: 2.2085e-04
# Epoch 391/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.4842e-04 - val_loss: 2.0303e-04
# Epoch 392/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.4620e-04 - val_loss: 6.8527e-04
# Epoch 393/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4785e-04 - val_loss: 2.0160e-04
# Epoch 394/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4755e-04 - val_loss: 5.3336e-04
# Epoch 395/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2821e-04 - val_loss: 2.1297e-04
# Epoch 396/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4069e-04 - val_loss: 2.8690e-04
# Epoch 397/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.7656e-04 - val_loss: 2.5669e-04
# Epoch 398/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.2788e-04 - val_loss: 4.9706e-04
# Epoch 399/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.8495e-04 - val_loss: 6.6974e-04
# Epoch 400/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4824e-04 - val_loss: 2.6313e-04
# Epoch 401/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3762e-04 - val_loss: 2.3041e-04
# Epoch 402/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3552e-04 - val_loss: 3.3383e-04
# Epoch 403/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1312e-04 - val_loss: 2.1040e-04
# Epoch 404/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1573e-04 - val_loss: 2.0683e-04
# Epoch 405/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.1716e-04 - val_loss: 2.1448e-04
# Epoch 406/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.6751e-04 - val_loss: 4.1513e-04
# Epoch 407/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.1196e-04 - val_loss: 2.1453e-04
# Epoch 408/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.1247e-04 - val_loss: 2.1295e-04
# Epoch 409/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.0410e-04 - val_loss: 4.2840e-04
# Epoch 410/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2485e-04 - val_loss: 1.9751e-04
# Epoch 411/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4439e-04 - val_loss: 2.2492e-04
# Epoch 412/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3300e-04 - val_loss: 1.5714e-04
# Epoch 413/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2967e-04 - val_loss: 2.6782e-04
# Epoch 414/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4308e-04 - val_loss: 4.8309e-04
# Epoch 415/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2508e-04 - val_loss: 2.0863e-04
# Epoch 416/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0982e-04 - val_loss: 1.1680e-04
# Epoch 417/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.6417e-04 - val_loss: 1.5780e-04
# Epoch 418/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0172e-04 - val_loss: 2.5394e-0418
# Epoch 419/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2315e-04 - val_loss: 5.4492e-04
# Epoch 420/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0574e-04 - val_loss: 1.9267e-04
# Epoch 421/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.3058e-04 - val_loss: 1.5181e-04
# Epoch 422/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1985e-04 - val_loss: 3.4697e-04
# Epoch 423/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0245e-04 - val_loss: 1.2843e-04
# Epoch 424/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1100e-04 - val_loss: 9.2165e-04
# Epoch 425/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2071e-04 - val_loss: 2.1520e-04
# Epoch 426/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1475e-04 - val_loss: 2.2138e-04
# Epoch 427/500
# 427/427 [==============================] - 3s 7ms/step - loss: 3.9627e-04 - val_loss: 2.6373e-04
# Epoch 428/500
# 427/427 [==============================] - 3s 7ms/step - loss: 4.5053e-04 - val_loss: 1.5491e-04
# Epoch 429/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8040e-04 - val_loss: 2.4913e-04
# Epoch 430/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6848e-04 - val_loss: 5.7105e-04
# Epoch 431/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2040e-04 - val_loss: 2.8713e-04
# Epoch 432/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7191e-04 - val_loss: 1.9117e-04
# Epoch 433/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1608e-04 - val_loss: 2.3657e-04
# Epoch 434/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.4528e-04 - val_loss: 1.4856e-04
# Epoch 435/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0602e-04 - val_loss: 3.6247e-04
# Epoch 436/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9149e-04 - val_loss: 2.0165e-04
# Epoch 437/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2863e-04 - val_loss: 1.7834e-04
# Epoch 438/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9963e-04 - val_loss: 1.2655e-04
# Epoch 439/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9523e-04 - val_loss: 2.5264e-04
# Epoch 440/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.2387e-04 - val_loss: 2.2164e-04
# Epoch 441/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9850e-04 - val_loss: 3.9582e-04
# Epoch 442/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0042e-04 - val_loss: 2.4398e-04
# Epoch 443/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7015e-04 - val_loss: 1.3714e-04
# Epoch 444/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7455e-04 - val_loss: 4.4692e-04
# Epoch 445/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0393e-04 - val_loss: 5.5086e-04
# Epoch 446/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6950e-04 - val_loss: 3.0756e-04
# Epoch 447/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1389e-04 - val_loss: 1.7893e-04
# Epoch 448/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1458e-04 - val_loss: 4.9814e-04
# Epoch 449/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0007e-04 - val_loss: 3.5465e-04
# Epoch 450/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8680e-04 - val_loss: 5.2229e-04
# Epoch 451/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1824e-04 - val_loss: 1.2292e-04
# Epoch 452/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8527e-04 - val_loss: 2.3834e-04
# Epoch 453/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7960e-04 - val_loss: 1.7269e-04
# Epoch 454/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0574e-04 - val_loss: 3.0444e-04
# Epoch 455/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9220e-04 - val_loss: 2.3101e-04
# Epoch 456/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1146e-04 - val_loss: 2.1163e-04
# Epoch 457/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8804e-04 - val_loss: 3.6055e-04
# Epoch 458/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.1476e-04 - val_loss: 6.1017e-04
# Epoch 459/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8866e-04 - val_loss: 1.4452e-04
# Epoch 460/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0817e-04 - val_loss: 4.4981e-04
# Epoch 461/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8054e-04 - val_loss: 1.6238e-04
# Epoch 462/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5820e-04 - val_loss: 2.5861e-04
# Epoch 463/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5004e-04 - val_loss: 1.9742e-04
# Epoch 464/500
# 427/427 [==============================] - 3s 6ms/step - loss: 4.0024e-04 - val_loss: 2.4573e-04
# Epoch 465/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6445e-04 - val_loss: 1.8553e-04
# Epoch 466/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7788e-04 - val_loss: 3.0521e-04
# Epoch 467/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9343e-04 - val_loss: 9.8778e-04
# Epoch 468/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8378e-04 - val_loss: 4.1750e-04
# Epoch 469/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.4728e-04 - val_loss: 2.5498e-04
# Epoch 470/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7353e-04 - val_loss: 7.8537e-04
# Epoch 471/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.4273e-04 - val_loss: 1.6399e-04
# Epoch 472/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8502e-04 - val_loss: 2.7359e-04
# Epoch 473/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8871e-04 - val_loss: 1.7055e-04
# Epoch 474/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8332e-04 - val_loss: 4.4135e-04
# Epoch 475/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8165e-04 - val_loss: 1.8882e-04
# Epoch 476/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7830e-04 - val_loss: 7.6012e-04
# Epoch 477/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5852e-04 - val_loss: 4.4604e-04
# Epoch 478/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6864e-04 - val_loss: 2.6441e-04
# Epoch 479/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9177e-04 - val_loss: 1.6004e-04
# Epoch 480/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6541e-04 - val_loss: 3.0834e-04
# Epoch 481/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7344e-04 - val_loss: 5.9596e-04
# Epoch 482/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7323e-04 - val_loss: 3.8576e-04
# Epoch 483/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7419e-04 - val_loss: 2.8798e-04
# Epoch 484/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9391e-04 - val_loss: 3.4371e-04
# Epoch 485/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5315e-04 - val_loss: 1.7673e-04
# Epoch 486/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7680e-04 - val_loss: 2.5299e-04
# Epoch 487/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6313e-04 - val_loss: 1.5904e-04
# Epoch 488/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.8564e-04 - val_loss: 1.8847e-04
# Epoch 489/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.9555e-04 - val_loss: 1.6286e-04
# Epoch 490/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5833e-04 - val_loss: 2.3086e-04
# Epoch 491/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5861e-04 - val_loss: 1.8928e-04
# Epoch 492/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6628e-04 - val_loss: 1.2319e-04
# Epoch 493/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.3441e-04 - val_loss: 2.0739e-04
# Epoch 494/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.6953e-04 - val_loss: 1.6589e-04
# Epoch 495/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.7423e-04 - val_loss: 1.4187e-04
# Epoch 496/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.4973e-04 - val_loss: 1.7708e-04
# Epoch 497/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.4849e-04 - val_loss: 1.8612e-04
# Epoch 498/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.3310e-04 - val_loss: 5.5315e-04
# Epoch 499/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5965e-04 - val_loss: 1.5698e-04
# Epoch 500/500
# 427/427 [==============================] - 3s 6ms/step - loss: 3.5800e-04 - val_loss: 2.3823e-04
# duree totale est de : 23.077167642116546

# %%
plot_model(model, show_shapes=True, to_file='Architecture hybride Auto-Encoder-Prédicteur.png')

# %%
# 4.3.2 : reshapping ou flattering des données par une fonction

def flatten(x):
    flattened_x=np.empty((x.shape[0],x.shape[2]))
    for i in range(x.shape[0]):
        flattened_x[i]=x[i,(x.shape[1]-1),:]
    return(flattened_x)
# 4.2 : Graphique loss & val_loss
plt.figure(figsize=(18,10)) 
plt.subplot(2,2,1)
plt.plot(history.history['loss'],label='Données d"entrainement')
plt.plot(history.history['val_loss'],label='Données Test')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.title('Loss & Epoch :Données d"entrainement et Données Test')
plt.legend()
# 4.3 :  Prédiction des données Test et d'entrainement par le modèle hybride
# model = load_model('modelAutoEncoderProjet.h5')
pred_x_train = model.predict(x_train)
pred_x_test = model.predict(x_test, verbose=0)
pred_x_dataset_full = model.predict(x_dataset_full, verbose=0)
# 4.3.3 : Visualisation des données origines et des données reconstituées

# plt.plot(test.date,test.cpu,'r--',label='data test')

dataset_test_set=dataset_test[timesteps:]

plt.subplot(2,2,2)

# plt.plot(dataset_test_set.date,dataset_test_set.cpu,marker='v',label='Données Test')

plt.plot(scaler.inverse_transform(flatten(x_test)),marker='v',label='Données Test')
plt.plot(scaler.inverse_transform(flatten(pred_x_test)),'r--',label='Données Test reconstituées')
plt.title('Ajustement données Test Origines & Réconstituées')
plt.legend()
plt.show()

# %%
# 4.3.4 : calcul du mse 

train_mse_loss=np.mean(np.power(flatten(x_train)-flatten(pred_x_train),2),axis=1) 
test_mse_loss=np.mean(np.power(flatten(x_test)-flatten(pred_x_test ),2),axis=1) 
full_mse_loss=np.mean(np.power(flatten(x_dataset_full)-flatten(pred_x_dataset_full),2),axis=1) 

# 4.3.5 :calcul du seuil pour determiner les anomalies

Erreurs=flatten(x_dataset_full)-flatten(pred_x_dataset_full)
sns.distplot(Erreurs,bins=50,kde=True)
plt.title('Distribution des Erreurs dataset total')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
THRESHOLD=0.002
plt.figure(figsize=(18,15)) 
plt.subplot(2,2,1) 
sns.distplot(test_mse_loss,bins=50,kde=True)
plt.title('Distribution du MSE(mean Squared Error) Test')
plt.legend()

# 4.3.5 : Constitution de la data anomalies ; on joue alors sur le niveau du seuil ex:THRESHOLD=0.96
test_score_df = pd.DataFrame(index=dataset_test[timesteps:].date)
test_score_df['loss']=test_mse_loss
test_score_df['cpu']=scaler.inverse_transform(flatten(x_test))
test_score_df['cpu_predit']=scaler.inverse_transform(flatten(pred_x_test))
test_score_df['THRESHOLD']=THRESHOLD
test_score_df['anomalie']=test_score_df.loss>test_score_df.THRESHOLD

# 5 : graphique des anomalies

# 5.1 : graphique des anomalies, du niveau de la courbe des pertes et du seuil
plt.subplot(2,2,2) 
plt.plot(test_score_df.index,test_score_df.loss,label='loss')
plt.plot(test_score_df.index,test_score_df.THRESHOLD,label='threshold')
plt.xticks(rotation=25)
plt.title('Evolution MSE(mean Squared Error) données Test')
plt.legend()

# 5.2 : calcul des anomalies

anomalies= test_score_df[test_score_df.anomalie]

# 5.3 : affichage des anomalies sur le graphique

anomalies=test_score_df[test_score_df.anomalie==True]

print('nombre d''anomalies: ',anomalies.shape[0])

# plt.figure(figsize=(18,15))
plt.subplot(2,2,3)
plt.plot(test_score_df.index,test_score_df.cpu,'r+:',label='cpu d''origine');
plt.plot(test_score_df.index,test_score_df.cpu_predit,marker='v',label='prediction data test prédite');
sns.scatterplot(
    anomalies.index,anomalies.cpu,
    color=sns.color_palette()[3],
    s=52,
    label='anomalie')
plt.xticks(rotation=25)
plt.xlabel('Minutes,heures, jour')
plt.ylabel('% cpu')
plt.title('Niveau des anomalies - seuil MSE(0.004)- Données Test: %2.0f'%(anomalies.shape[0]) + ' anomalies')
plt.legend();

# ajouter nbre d'anomalie dans le graphique: print('nombre d''anomalies: ',anomalies.shape[0])
# A partir d'ici juste les essaies avec  les données de validation

# 6 - données validation

full_score_df=pd.DataFrame(index=dataset_full[timesteps:].date)
full_score_df['loss']=full_mse_loss
full_score_df['cpu']=scaler.inverse_transform(flatten(x_dataset_full))
full_score_df['cpu_predit']=scaler.inverse_transform(flatten(pred_x_dataset_full))
full_score_df['THRESHOLD']=THRESHOLD
full_score_df['anomalie']=full_score_df.loss>full_score_df.THRESHOLD

anomalies_full= full_score_df[full_score_df.anomalie]
anomalies_full=full_score_df[full_score_df.anomalie==True]
# plt.figure(figsize=(18,15))
plt.subplot(2,2,4)
plt.plot(full_score_df.index,full_score_df.cpu,'r+:',label='cpu d''origine');
plt.plot(full_score_df.index,full_score_df.cpu_predit,marker='v',label='prediction data validation');
sns.scatterplot(
    anomalies_full.index,anomalies_full.cpu,
    color=sns.color_palette()[3],
    s=52,
    label='anomalie')
plt.xticks(rotation=25)
plt.xlabel('Minutes,heures, jour') 
plt.ylabel('% cpu') 
plt.title('Niveau des anomalies - seuil MSE(0.004)- Données Totale : %2.0f'%(anomalies_full.shape[0]) + ' anomalies')
plt.legend()
plt.show();
# Out:
# No handles with labels found to put in legend.
# nombre danomalies:  4

# %%
# 6 - calcul des anomalies par les erreures de prediction
THRESHOLD=0.04
plt.figure(figsize=(18,15)) 
plt.subplot(2,2,1) 
Erreurs=flatten(x_dataset_full)-flatten(pred_x_dataset_full)
sns.distplot(Erreurs,bins=50,kde=True)
plt.title('Distribution des Erreurs sur l"Ensemble des Données')
plt.legend()
# 4.3.5 : Constitution de la data anomalies ; on joue alors sur le niveau du seuil ex:THRESHOLD=0.96
test_score_df = pd.DataFrame(index=dataset_test[timesteps:].date)
test_score_df['loss']=flatten(x_test)-flatten(pred_x_test)
test_score_df['cpu']=scaler.inverse_transform(flatten(x_test))
test_score_df['cpu_predit']=scaler.inverse_transform(flatten(pred_x_test))
test_score_df['THRESHOLD']=THRESHOLD
test_score_df['anomalie']=test_score_df.loss>test_score_df.THRESHOLD

# 5 : graphique des anomalies

# 5.1 : graphique des anomalies, du niveau de la courbe des pertes et du seuil
plt.subplot(2,2,2) 
plt.plot(test_score_df.index,test_score_df.loss,label='loss')
plt.plot(test_score_df.index,test_score_df.THRESHOLD,label='threshold')
plt.xticks(rotation=25)
plt.title('Erreurs de reconstruction sur les données Test')
plt.legend()

# 5.2 : calcul des anomalies

anomalies= test_score_df[test_score_df.anomalie]

# 5.3 : affichage des anomalies sur le graphique

anomalies=test_score_df[test_score_df.anomalie==True]

print('nombre d''anomalies: ',anomalies.shape[0])

# plt.figure(figsize=(18,15))
plt.subplot(2,2,3)
plt.plot(test_score_df.index,test_score_df.cpu,'r+:',label='cpu d''origine');
plt.plot(test_score_df.index,test_score_df.cpu_predit,marker='v',label='prediction data test prédite');
sns.scatterplot(
    anomalies.index,anomalies.cpu,
    color=sns.color_palette()[3],
    s=52,
    label='anomalie')
plt.xticks(rotation=25)
plt.xlabel('Minutes,heures, jour')
plt.ylabel('% cpu')
plt.title('Nombre d"anomalies detectées au seuil Erreurs(0.06) sur les Données Test: %2.0f'%(anomalies.shape[0]))
plt.legend();

# ajouter nbre d'anomalie dans le graphique: print('nombre d''anomalies: ',anomalies.shape[0])

# 6 - données totale

full_score_df=pd.DataFrame(index=dataset_full[timesteps:].date)
full_score_df['loss']=flatten(x_dataset_full)-flatten(pred_x_dataset_full)
full_score_df['cpu']=scaler.inverse_transform(flatten(x_dataset_full))
full_score_df['cpu_predit']=scaler.inverse_transform(flatten(pred_x_dataset_full))
full_score_df['THRESHOLD']=THRESHOLD
full_score_df['anomalie']=full_score_df.loss>full_score_df.THRESHOLD

anomalies_full= full_score_df[full_score_df.anomalie]
anomalies_full=full_score_df[full_score_df.anomalie==True]
# plt.figure(figsize=(18,15))
plt.subplot(2,2,4)
plt.plot(full_score_df.index,full_score_df.cpu,'r+:',label='cpu d''origine');
plt.plot(full_score_df.index,full_score_df.cpu_predit,marker='v',label='prediction data validation');
sns.scatterplot(
    anomalies_full.index,anomalies_full.cpu,
    color=sns.color_palette()[3],
    s=52,
    label='anomalie')
plt.xticks(rotation=25)
plt.xlabel('Minutes,heures, jour') 
plt.ylabel('% cpu') 
plt.title('Nombre d"anomalies detectées au seuil Erreurs(0.06) sur les Données Totale : %2.0f'%(anomalies_full.shape[0]))
plt.legend()
plt.show();
# Out:
# No handles with labels found to put in legend.
# nombre danomalies:  3
